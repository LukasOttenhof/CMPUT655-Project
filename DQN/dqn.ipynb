# %%
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from tqdm import tqdm
from rl_glue import RLGlue

from tbu_gym.tbu_discrete import TruckBackerEnv_D

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-5, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, buffer_size=50000, batch_size=64):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.memory = deque(maxlen=buffer_size)
        # device, not needed, but needed if going on canada compute to specify gpu
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.q_nn = self.build_nn().to(self.device) # build q network
        self.target_net = self.build_nn().to(self.device) # build target network
        self.target_net.load_state_dict(self.q_nn.state_dict()) # make target net same as q net. initialization is random so need this
        self.optimizer = optim.Adam(self.q_nn.parameters(), lr=lr) 
        
    def build_nn(self): # to build the q network, 2 hiddne layer with relu and 128 neuronsin each
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_dim)
        )
    
    def agent_policy(self, state): # act e greedy
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim) # rand action
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device) # convert state to tensor, then add batch dimension, then move to device
        with torch.no_grad(): # dont calculate gradients, no need
            q_values = self.q_nn(state)
        return q_values.argmax().item()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # store transition sars, done is if terminal state
    
    def train_with_mem(self): # train with experience from memory using batch size set in agent
        if len(self.memory) < self.batch_size: # if not enought mem, could be changed to use what we have instead of skip
            return
        batch = random.sample(self.memory, self.batch_size) # get batch
        states, actions, rewards, next_states, dones = zip(*batch) # get batch features

        # convert data to tensors which can be used by pytorch
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device) 
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # get current q values from q network
        q_values = self.q_nn(states).gather(1, actions)

        # use the samples from experience batch to calc target network q values
        with torch.no_grad(): # no need to calc gradients for target
            next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]  
        # target = r + gamma * max_a' Q(s', a') * (1 - done)
        target = rewards + self.gamma * next_q_values * (1 - dones)

        # mean squared error 
        errors = target - q_values
        squared_errors = errors ** 2
        mean_squared_error = torch.mean(squared_errors)

        self.optimizer.zero_grad()
        mean_squared_error.backward()
        self.optimizer.step()
 
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay 

    
    def update_target(self): # update target network replacing it with the current q network
        self.target_net.load_state_dict(self.q_nn.state_dict())

# %%
import numpy as np
from tbu_gym.tbu_discrete import TruckBackerEnv_D
import matplotlib.pyplot as plt

#hyper params, these are set by default in the agent but can be changed here
num_episodes = 1000
max_steps_per_episode = 500
gamma = 0.99
learning_rate = 1e-3
epsilon_start = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01
batch_size = 64
target_update_freq = 10  # Update target network every N episodes

#agent env setup
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

agent = DQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    lr=learning_rate,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    epsilon_min=epsilon_min,
    batch_size=batch_size
)

#training
episode_rewards = []

for episode in range(1, num_episodes + 1):
    state = env.reset()
    total_reward = 0

    for t in range(max_steps_per_episode):
    
        action = agent.agent_policy(state) # e greedy action

        # step env
        next_state, reward, done, info = env.step(action) # do a observe s',r and if terminal
        total_reward += reward

        #store transition in memory
        agent.remember(state, action, reward, next_state, done) # set s' = s a r and if terminal

        # train agent with memory, will train with batch size set in agent
        agent.train_with_mem() 

        state = next_state #s = s'

        if done: # if terminal state
            break


    if episode % target_update_freq == 0:
        agent.update_target()

    episode_rewards.append(total_reward)
    
    print(f"Episode {episode}, Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")


plt.plot(episode_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN Training on TruckBackerEnv_D')
plt.show()
# Out:
# Episode 1, Reward: -300, Epsilon: 0.305
# Episode 2, Reward: -300, Epsilon: 0.068
# Episode 3, Reward: -300, Epsilon: 0.015
# Episode 4, Reward: -300, Epsilon: 0.010
# Episode 5, Reward: -300, Epsilon: 0.010
# Episode 6, Reward: -300, Epsilon: 0.010
# Episode 7, Reward: -300, Epsilon: 0.010
# Episode 8, Reward: -300, Epsilon: 0.010
# Episode 9, Reward: -300, Epsilon: 0.010
# Episode 10, Reward: -300, Epsilon: 0.010
# Episode 11, Reward: -300, Epsilon: 0.010
# Episode 12, Reward: -300, Epsilon: 0.010
# Episode 13, Reward: -300, Epsilon: 0.010
# Episode 14, Reward: -300, Epsilon: 0.010
# Episode 15, Reward: -300, Epsilon: 0.010
# Episode 16, Reward: -300, Epsilon: 0.010
# Episode 17, Reward: -300, Epsilon: 0.010
# Episode 18, Reward: -300, Epsilon: 0.010
# Episode 19, Reward: -300, Epsilon: 0.010
# Episode 20, Reward: -300, Epsilon: 0.010
# Episode 21, Reward: -300, Epsilon: 0.010
# Episode 22, Reward: -300, Epsilon: 0.010
# Episode 23, Reward: -300, Epsilon: 0.010
# Episode 24, Reward: -300, Epsilon: 0.010
# Episode 25, Reward: -300, Epsilon: 0.010
# Episode 26, Reward: -300, Epsilon: 0.010
# Episode 27, Reward: -300, Epsilon: 0.010
# Episode 28, Reward: -300, Epsilon: 0.010
# Episode 29, Reward: -300, Epsilon: 0.010
# Episode 30, Reward: -300, Epsilon: 0.010
# Episode 31, Reward: -300, Epsilon: 0.010
# Episode 32, Reward: -300, Epsilon: 0.010
# Episode 33, Reward: -300, Epsilon: 0.010
# Episode 34, Reward: -300, Epsilon: 0.010
# Episode 35, Reward: -300, Epsilon: 0.010
# Episode 36, Reward: -300, Epsilon: 0.010
# Episode 37, Reward: -300, Epsilon: 0.010
# Episode 38, Reward: -300, Epsilon: 0.010
# Episode 39, Reward: -300, Epsilon: 0.010
# Episode 40, Reward: -300, Epsilon: 0.010
# Episode 41, Reward: -300, Epsilon: 0.010
# Episode 42, Reward: -300, Epsilon: 0.010
# Episode 43, Reward: -300, Epsilon: 0.010
# Episode 44, Reward: -300, Epsilon: 0.010
# Episode 45, Reward: -300, Epsilon: 0.010
# Episode 46, Reward: -300, Epsilon: 0.010
# Episode 47, Reward: -300, Epsilon: 0.010
# Episode 48, Reward: -300, Epsilon: 0.010
# Episode 49, Reward: -300, Epsilon: 0.010
# Episode 50, Reward: -300, Epsilon: 0.010
# Episode 51, Reward: -300, Epsilon: 0.010
# Episode 52, Reward: -300, Epsilon: 0.010
# Episode 53, Reward: -300, Epsilon: 0.010
# Episode 54, Reward: -300, Epsilon: 0.010
# Episode 55, Reward: -300, Epsilon: 0.010
# Episode 56, Reward: -300, Epsilon: 0.010
# Episode 57, Reward: -300, Epsilon: 0.010
# Episode 58, Reward: -300, Epsilon: 0.010
# Episode 59, Reward: -300, Epsilon: 0.010
# Episode 60, Reward: -300, Epsilon: 0.010
# Episode 61, Reward: -300, Epsilon: 0.010
# Episode 62, Reward: -300, Epsilon: 0.010
# Episode 63, Reward: -300, Epsilon: 0.010
# Episode 64, Reward: -300, Epsilon: 0.010
# Episode 65, Reward: -300, Epsilon: 0.010
# Episode 66, Reward: -300, Epsilon: 0.010
# Episode 67, Reward: -300, Epsilon: 0.010
# Episode 68, Reward: -300, Epsilon: 0.010
# Episode 69, Reward: -300, Epsilon: 0.010
# Episode 70, Reward: -28, Epsilon: 0.010
# Episode 71, Reward: -300, Epsilon: 0.010
# Episode 72, Reward: -14, Epsilon: 0.010
# Episode 73, Reward: -300, Epsilon: 0.010
# Episode 74, Reward: -300, Epsilon: 0.010
# Episode 75, Reward: -300, Epsilon: 0.010
# Episode 76, Reward: -300, Epsilon: 0.010
# Episode 77, Reward: -300, Epsilon: 0.010
# Episode 78, Reward: -300, Epsilon: 0.010
# Episode 79, Reward: -300, Epsilon: 0.010
# Episode 80, Reward: -300, Epsilon: 0.010
# Episode 81, Reward: -300, Epsilon: 0.010
# Episode 82, Reward: -300, Epsilon: 0.010
# Episode 83, Reward: -300, Epsilon: 0.010
# Episode 84, Reward: -300, Epsilon: 0.010
# Episode 85, Reward: -300, Epsilon: 0.010
# Episode 86, Reward: -300, Epsilon: 0.010
# Episode 87, Reward: -300, Epsilon: 0.010
# Episode 88, Reward: -300, Epsilon: 0.010
# Episode 89, Reward: -300, Epsilon: 0.010
# Episode 90, Reward: -300, Epsilon: 0.010
# Episode 91, Reward: -300, Epsilon: 0.010
# Episode 92, Reward: -300, Epsilon: 0.010
# Episode 93, Reward: -300, Epsilon: 0.010
# Episode 94, Reward: -300, Epsilon: 0.010
# Episode 95, Reward: -300, Epsilon: 0.010
# Episode 96, Reward: -300, Epsilon: 0.010
# Episode 97, Reward: -300, Epsilon: 0.010
# Episode 98, Reward: -300, Epsilon: 0.010
# Episode 99, Reward: -300, Epsilon: 0.010
# Episode 100, Reward: -300, Epsilon: 0.010
# Episode 101, Reward: -300, Epsilon: 0.010
# Episode 102, Reward: -300, Epsilon: 0.010
# Episode 103, Reward: -300, Epsilon: 0.010
# Episode 104, Reward: -300, Epsilon: 0.010
# Episode 105, Reward: -300, Epsilon: 0.010
# Episode 106, Reward: -300, Epsilon: 0.010
# Episode 107, Reward: -300, Epsilon: 0.010
# Episode 108, Reward: -300, Epsilon: 0.010
# Episode 109, Reward: -300, Epsilon: 0.010
# Episode 110, Reward: -300, Epsilon: 0.010
# Episode 111, Reward: -300, Epsilon: 0.010
# Episode 112, Reward: -300, Epsilon: 0.010
# Episode 113, Reward: -300, Epsilon: 0.010
# Episode 114, Reward: -300, Epsilon: 0.010
# Episode 115, Reward: -300, Epsilon: 0.010
# Episode 116, Reward: -300, Epsilon: 0.010
# Episode 117, Reward: -300, Epsilon: 0.010
# Episode 118, Reward: -172, Epsilon: 0.010
# Episode 119, Reward: -300, Epsilon: 0.010
# Episode 120, Reward: -300, Epsilon: 0.010
# Episode 121, Reward: -300, Epsilon: 0.010
# Episode 122, Reward: -300, Epsilon: 0.010
# Episode 123, Reward: -300, Epsilon: 0.010
# Episode 124, Reward: -300, Epsilon: 0.010
# Episode 125, Reward: -300, Epsilon: 0.010
# Episode 126, Reward: -300, Epsilon: 0.010
# Episode 127, Reward: -300, Epsilon: 0.010
# Episode 128, Reward: -300, Epsilon: 0.010
# Episode 129, Reward: -300, Epsilon: 0.010
# Episode 130, Reward: -300, Epsilon: 0.010
# Episode 131, Reward: -300, Epsilon: 0.010
# Episode 132, Reward: 36, Epsilon: 0.010
# Episode 133, Reward: -300, Epsilon: 0.010
# Episode 134, Reward: -300, Epsilon: 0.010
# Episode 135, Reward: -300, Epsilon: 0.010
# Episode 136, Reward: -300, Epsilon: 0.010
# Episode 137, Reward: -300, Epsilon: 0.010
# Episode 138, Reward: -300, Epsilon: 0.010
# Episode 139, Reward: -300, Epsilon: 0.010
# Episode 140, Reward: -300, Epsilon: 0.010
# Episode 141, Reward: -300, Epsilon: 0.010
# Episode 142, Reward: -300, Epsilon: 0.010
# Episode 143, Reward: -300, Epsilon: 0.010
# Episode 144, Reward: -300, Epsilon: 0.010
# Episode 145, Reward: -300, Epsilon: 0.010
# Episode 146, Reward: -300, Epsilon: 0.010
# Episode 147, Reward: -300, Epsilon: 0.010
# Episode 148, Reward: -300, Epsilon: 0.010
# Episode 149, Reward: -300, Epsilon: 0.010
# Episode 150, Reward: -300, Epsilon: 0.010
# Episode 151, Reward: -300, Epsilon: 0.010
# Episode 152, Reward: -300, Epsilon: 0.010
# Episode 153, Reward: -300, Epsilon: 0.010
# Episode 154, Reward: -300, Epsilon: 0.010
# Episode 155, Reward: -300, Epsilon: 0.010
# Episode 156, Reward: -300, Epsilon: 0.010
# Episode 157, Reward: -300, Epsilon: 0.010
# Episode 158, Reward: -300, Epsilon: 0.010
# Episode 159, Reward: -300, Epsilon: 0.010
# Episode 160, Reward: -300, Epsilon: 0.010
# Episode 161, Reward: -300, Epsilon: 0.010
# Episode 162, Reward: -300, Epsilon: 0.010
# Episode 163, Reward: -300, Epsilon: 0.010
# Episode 164, Reward: -300, Epsilon: 0.010
# Episode 165, Reward: -300, Epsilon: 0.010
# Episode 166, Reward: -300, Epsilon: 0.010
# Episode 167, Reward: -300, Epsilon: 0.010
# Episode 168, Reward: -300, Epsilon: 0.010
# Episode 169, Reward: -300, Epsilon: 0.010
# Episode 170, Reward: -300, Epsilon: 0.010
# Episode 171, Reward: -300, Epsilon: 0.010
# Episode 172, Reward: -300, Epsilon: 0.010
# Episode 173, Reward: -300, Epsilon: 0.010
# Episode 174, Reward: -179, Epsilon: 0.010
# Episode 175, Reward: -32, Epsilon: 0.010
# Episode 176, Reward: 53, Epsilon: 0.010
# Episode 177, Reward: -300, Epsilon: 0.010
# Episode 178, Reward: -300, Epsilon: 0.010
# Episode 179, Reward: -300, Epsilon: 0.010
# Episode 180, Reward: -300, Epsilon: 0.010
# Episode 181, Reward: -300, Epsilon: 0.010
# Episode 182, Reward: -300, Epsilon: 0.010
# Episode 183, Reward: -300, Epsilon: 0.010
# Episode 184, Reward: -300, Epsilon: 0.010
# Episode 185, Reward: -300, Epsilon: 0.010
# Episode 186, Reward: -300, Epsilon: 0.010
# Episode 187, Reward: -300, Epsilon: 0.010
# Episode 188, Reward: -300, Epsilon: 0.010
# Episode 189, Reward: -300, Epsilon: 0.010
# Episode 190, Reward: -300, Epsilon: 0.010
# Episode 191, Reward: -300, Epsilon: 0.010
# Episode 192, Reward: -300, Epsilon: 0.010
# Episode 193, Reward: -300, Epsilon: 0.010
# Episode 194, Reward: -300, Epsilon: 0.010
# Episode 195, Reward: -300, Epsilon: 0.010
# Episode 196, Reward: -300, Epsilon: 0.010
# Episode 197, Reward: -300, Epsilon: 0.010
# Episode 198, Reward: -300, Epsilon: 0.010
# Episode 199, Reward: -300, Epsilon: 0.010
# Episode 200, Reward: -300, Epsilon: 0.010
# Episode 201, Reward: -300, Epsilon: 0.010
# Episode 202, Reward: -300, Epsilon: 0.010
# Episode 203, Reward: -300, Epsilon: 0.010
# Episode 204, Reward: -300, Epsilon: 0.010
# Episode 205, Reward: -300, Epsilon: 0.010
# Episode 206, Reward: -300, Epsilon: 0.010
# Episode 207, Reward: -300, Epsilon: 0.010
# Episode 208, Reward: -300, Epsilon: 0.010
# Episode 209, Reward: -96, Epsilon: 0.010
# Episode 210, Reward: -300, Epsilon: 0.010
# Episode 211, Reward: -300, Epsilon: 0.010
# Episode 212, Reward: -300, Epsilon: 0.010
# Episode 213, Reward: -300, Epsilon: 0.010
# Episode 214, Reward: -300, Epsilon: 0.010
# Episode 215, Reward: -300, Epsilon: 0.010
# Episode 216, Reward: -300, Epsilon: 0.010
# Episode 217, Reward: -300, Epsilon: 0.010
# Episode 218, Reward: -300, Epsilon: 0.010
# Episode 219, Reward: -300, Epsilon: 0.010
# Episode 220, Reward: -300, Epsilon: 0.010
# Episode 221, Reward: -300, Epsilon: 0.010
# Episode 222, Reward: -300, Epsilon: 0.010
# Episode 223, Reward: -300, Epsilon: 0.010
# Episode 224, Reward: -300, Epsilon: 0.010
# Episode 225, Reward: -300, Epsilon: 0.010
# Episode 226, Reward: -78, Epsilon: 0.010
# Episode 227, Reward: -300, Epsilon: 0.010
# Episode 228, Reward: -300, Epsilon: 0.010
# Episode 229, Reward: -300, Epsilon: 0.010
# Episode 230, Reward: -300, Epsilon: 0.010
# Episode 231, Reward: -300, Epsilon: 0.010
# Episode 232, Reward: -300, Epsilon: 0.010
# Episode 233, Reward: -300, Epsilon: 0.010
# Episode 234, Reward: -300, Epsilon: 0.010
# Episode 235, Reward: -300, Epsilon: 0.010
# Episode 236, Reward: -300, Epsilon: 0.010
# Episode 237, Reward: -300, Epsilon: 0.010
# Episode 238, Reward: -300, Epsilon: 0.010
# Episode 239, Reward: -300, Epsilon: 0.010
# Episode 240, Reward: -300, Epsilon: 0.010
# Episode 241, Reward: -300, Epsilon: 0.010
# Episode 242, Reward: -300, Epsilon: 0.010
# Episode 243, Reward: 21, Epsilon: 0.010
# Episode 244, Reward: -300, Epsilon: 0.010
# Episode 245, Reward: -300, Epsilon: 0.010
# Episode 246, Reward: -300, Epsilon: 0.010
# Episode 247, Reward: -300, Epsilon: 0.010
# Episode 248, Reward: 54, Epsilon: 0.010
# Episode 249, Reward: -300, Epsilon: 0.010
# Episode 250, Reward: 40, Epsilon: 0.010
# Episode 251, Reward: -42, Epsilon: 0.010
# Episode 252, Reward: -300, Epsilon: 0.010
# Episode 253, Reward: -152, Epsilon: 0.010
# Episode 254, Reward: -300, Epsilon: 0.010
# Episode 255, Reward: -300, Epsilon: 0.010
# Episode 256, Reward: 28, Epsilon: 0.010
# Episode 257, Reward: -143, Epsilon: 0.010
# Episode 258, Reward: -300, Epsilon: 0.010
# Episode 259, Reward: -300, Epsilon: 0.010
# Episode 260, Reward: -300, Epsilon: 0.010
# Episode 261, Reward: -177, Epsilon: 0.010
# Episode 262, Reward: -104, Epsilon: 0.010
# Episode 263, Reward: 52, Epsilon: 0.010
# Episode 264, Reward: -300, Epsilon: 0.010
# Episode 265, Reward: -89, Epsilon: 0.010
# Episode 266, Reward: -300, Epsilon: 0.010
# Episode 267, Reward: -300, Epsilon: 0.010
# Episode 268, Reward: 26, Epsilon: 0.010
# Episode 269, Reward: -300, Epsilon: 0.010
# Episode 270, Reward: -300, Epsilon: 0.010
# Episode 271, Reward: -300, Epsilon: 0.010
# Episode 272, Reward: -127, Epsilon: 0.010
# Episode 273, Reward: 46, Epsilon: 0.010
# Episode 274, Reward: -300, Epsilon: 0.010
# Episode 275, Reward: 15, Epsilon: 0.010
# Episode 276, Reward: -300, Epsilon: 0.010
# Episode 277, Reward: 34, Epsilon: 0.010
# Episode 278, Reward: 44, Epsilon: 0.010
# Episode 279, Reward: -300, Epsilon: 0.010
# Episode 280, Reward: -27, Epsilon: 0.010
# Episode 281, Reward: 49, Epsilon: 0.010
# Episode 282, Reward: -300, Epsilon: 0.010
# Episode 283, Reward: 3, Epsilon: 0.010
# Episode 284, Reward: -29, Epsilon: 0.010
# Episode 285, Reward: -98, Epsilon: 0.010
# Episode 286, Reward: 49, Epsilon: 0.010
# Episode 287, Reward: -300, Epsilon: 0.010
# Episode 288, Reward: -129, Epsilon: 0.010
# Episode 289, Reward: -150, Epsilon: 0.010
# Episode 290, Reward: 62, Epsilon: 0.010
# Episode 291, Reward: 48, Epsilon: 0.010
# Episode 292, Reward: -300, Epsilon: 0.010
# Episode 293, Reward: 3, Epsilon: 0.010
# Episode 294, Reward: -19, Epsilon: 0.010
# Episode 295, Reward: -69, Epsilon: 0.010
# Episode 296, Reward: 62, Epsilon: 0.010
# Episode 297, Reward: -300, Epsilon: 0.010
# Episode 298, Reward: -300, Epsilon: 0.010
# Episode 299, Reward: 27, Epsilon: 0.010
# Episode 300, Reward: 43, Epsilon: 0.010
# Episode 301, Reward: -300, Epsilon: 0.010
# Episode 302, Reward: -300, Epsilon: 0.010
# Episode 303, Reward: 64, Epsilon: 0.010
# Episode 304, Reward: -300, Epsilon: 0.010
# Episode 305, Reward: -128, Epsilon: 0.010
# Episode 306, Reward: 55, Epsilon: 0.010
# Episode 307, Reward: 23, Epsilon: 0.010
# Episode 308, Reward: 58, Epsilon: 0.010
# Episode 309, Reward: -300, Epsilon: 0.010
# Episode 310, Reward: -4, Epsilon: 0.010
# Episode 311, Reward: 57, Epsilon: 0.010
# Episode 312, Reward: -300, Epsilon: 0.010
# Episode 313, Reward: 55, Epsilon: 0.010
# Episode 314, Reward: 43, Epsilon: 0.010
# Episode 315, Reward: -300, Epsilon: 0.010
# Episode 316, Reward: -174, Epsilon: 0.010
# Episode 317, Reward: -100, Epsilon: 0.010
# Episode 318, Reward: 49, Epsilon: 0.010
# Episode 319, Reward: 56, Epsilon: 0.010
# Episode 320, Reward: -300, Epsilon: 0.010
# Episode 321, Reward: -70, Epsilon: 0.010
# Episode 322, Reward: -5, Epsilon: 0.010
# Episode 323, Reward: -100, Epsilon: 0.010
# Episode 324, Reward: 0, Epsilon: 0.010
# Episode 325, Reward: -300, Epsilon: 0.010
# Episode 326, Reward: 55, Epsilon: 0.010
# Episode 327, Reward: 50, Epsilon: 0.010
# Episode 328, Reward: 65, Epsilon: 0.010
# Episode 329, Reward: 51, Epsilon: 0.010
# Episode 330, Reward: -189, Epsilon: 0.010
# Episode 331, Reward: 46, Epsilon: 0.010
# Episode 332, Reward: 61, Epsilon: 0.010
# Episode 333, Reward: -12, Epsilon: 0.010
# Episode 334, Reward: 61, Epsilon: 0.010
# Episode 335, Reward: 45, Epsilon: 0.010
# Episode 336, Reward: -76, Epsilon: 0.010
# Episode 337, Reward: 54, Epsilon: 0.010
# Episode 338, Reward: -300, Epsilon: 0.010
# Episode 339, Reward: -30, Epsilon: 0.010
# Episode 340, Reward: 57, Epsilon: 0.010
# Episode 341, Reward: 16, Epsilon: 0.010
# Episode 342, Reward: -300, Epsilon: 0.010
# Episode 343, Reward: 45, Epsilon: 0.010
# Episode 344, Reward: 61, Epsilon: 0.010
# Episode 345, Reward: -37, Epsilon: 0.010
# Episode 346, Reward: 61, Epsilon: 0.010
# Episode 347, Reward: 59, Epsilon: 0.010
# Episode 348, Reward: 53, Epsilon: 0.010
# Episode 349, Reward: 52, Epsilon: 0.010
# Episode 350, Reward: 10, Epsilon: 0.010
# Episode 351, Reward: 59, Epsilon: 0.010
# Episode 352, Reward: -26, Epsilon: 0.010
# Episode 353, Reward: 20, Epsilon: 0.010
# Episode 354, Reward: 4, Epsilon: 0.010
# Episode 355, Reward: -300, Epsilon: 0.010
# Episode 356, Reward: -300, Epsilon: 0.010
# Episode 357, Reward: -300, Epsilon: 0.010
# Episode 358, Reward: -7, Epsilon: 0.010
# Episode 359, Reward: 63, Epsilon: 0.010
# Episode 360, Reward: 47, Epsilon: 0.010
# Episode 361, Reward: 53, Epsilon: 0.010
# Episode 362, Reward: -2, Epsilon: 0.010
# Episode 363, Reward: 46, Epsilon: 0.010
# Episode 364, Reward: -42, Epsilon: 0.010
# Episode 365, Reward: 36, Epsilon: 0.010
# Episode 366, Reward: 55, Epsilon: 0.010
# Episode 367, Reward: 59, Epsilon: 0.010
# Episode 368, Reward: -5, Epsilon: 0.010
# Episode 369, Reward: -33, Epsilon: 0.010
# Episode 370, Reward: -38, Epsilon: 0.010
# Episode 371, Reward: 62, Epsilon: 0.010
# Episode 372, Reward: 6, Epsilon: 0.010
# Episode 373, Reward: 58, Epsilon: 0.010
# Episode 374, Reward: 19, Epsilon: 0.010
# Episode 375, Reward: 52, Epsilon: 0.010
# Episode 376, Reward: 9, Epsilon: 0.010
# Episode 377, Reward: 39, Epsilon: 0.010
# Episode 378, Reward: 35, Epsilon: 0.010
# Episode 379, Reward: 54, Epsilon: 0.010
# Episode 380, Reward: 28, Epsilon: 0.010
# Episode 381, Reward: 47, Epsilon: 0.010
# Episode 382, Reward: 40, Epsilon: 0.010
# Episode 383, Reward: 51, Epsilon: 0.010
# Episode 384, Reward: -105, Epsilon: 0.010
# Episode 385, Reward: -300, Epsilon: 0.010
# Episode 386, Reward: 62, Epsilon: 0.010
# Episode 387, Reward: -63, Epsilon: 0.010
# Episode 388, Reward: 35, Epsilon: 0.010
# Episode 389, Reward: 58, Epsilon: 0.010
# Episode 390, Reward: 52, Epsilon: 0.010
# Episode 391, Reward: 11, Epsilon: 0.010
# Episode 392, Reward: 44, Epsilon: 0.010
# Episode 393, Reward: 45, Epsilon: 0.010
# Episode 394, Reward: 50, Epsilon: 0.010
# Episode 395, Reward: 58, Epsilon: 0.010
# Episode 396, Reward: 41, Epsilon: 0.010
# Episode 397, Reward: 60, Epsilon: 0.010
# Episode 398, Reward: 63, Epsilon: 0.010
# Episode 399, Reward: -99, Epsilon: 0.010
# Episode 400, Reward: 41, Epsilon: 0.010
# Episode 401, Reward: 56, Epsilon: 0.010
# Episode 402, Reward: -60, Epsilon: 0.010
# Episode 403, Reward: 44, Epsilon: 0.010
# Episode 404, Reward: 54, Epsilon: 0.010
# Episode 405, Reward: 60, Epsilon: 0.010
# Episode 406, Reward: 40, Epsilon: 0.010
# Episode 407, Reward: 48, Epsilon: 0.010
# Episode 408, Reward: 54, Epsilon: 0.010
# Episode 409, Reward: 34, Epsilon: 0.010
# Episode 410, Reward: 40, Epsilon: 0.010
# Episode 411, Reward: 55, Epsilon: 0.010
# Episode 412, Reward: 44, Epsilon: 0.010
# Episode 413, Reward: 47, Epsilon: 0.010
# Episode 414, Reward: -1, Epsilon: 0.010
# Episode 415, Reward: 45, Epsilon: 0.010
# Episode 416, Reward: 33, Epsilon: 0.010
# Episode 417, Reward: 54, Epsilon: 0.010
# Episode 418, Reward: 47, Epsilon: 0.010
# Episode 419, Reward: 36, Epsilon: 0.010
# Episode 420, Reward: 34, Epsilon: 0.010
# Episode 421, Reward: 49, Epsilon: 0.010
# Episode 422, Reward: -179, Epsilon: 0.010
# Episode 423, Reward: 53, Epsilon: 0.010
# Episode 424, Reward: 64, Epsilon: 0.010
# Episode 425, Reward: 45, Epsilon: 0.010
# Episode 426, Reward: -45, Epsilon: 0.010
# Episode 427, Reward: 58, Epsilon: 0.010
# Episode 428, Reward: -13, Epsilon: 0.010
# Episode 429, Reward: 59, Epsilon: 0.010
# Episode 430, Reward: 52, Epsilon: 0.010
# Episode 431, Reward: 48, Epsilon: 0.010
# Episode 432, Reward: -84, Epsilon: 0.010
# Episode 433, Reward: 48, Epsilon: 0.010
# Episode 434, Reward: 38, Epsilon: 0.010
# Episode 435, Reward: 24, Epsilon: 0.010
# Episode 436, Reward: 52, Epsilon: 0.010
# Episode 437, Reward: 63, Epsilon: 0.010
# Episode 438, Reward: 64, Epsilon: 0.010
# Episode 439, Reward: 57, Epsilon: 0.010
# Episode 440, Reward: 3, Epsilon: 0.010
# Episode 441, Reward: 50, Epsilon: 0.010
# Episode 442, Reward: 42, Epsilon: 0.010
# Episode 443, Reward: -6, Epsilon: 0.010
# Episode 444, Reward: 44, Epsilon: 0.010
# Episode 445, Reward: 46, Epsilon: 0.010
# Episode 446, Reward: 58, Epsilon: 0.010
# Episode 447, Reward: 28, Epsilon: 0.010
# Episode 448, Reward: 40, Epsilon: 0.010
# Episode 449, Reward: 50, Epsilon: 0.010
# Episode 450, Reward: 63, Epsilon: 0.010
# Episode 451, Reward: -24, Epsilon: 0.010
# Episode 452, Reward: 38, Epsilon: 0.010
# Episode 453, Reward: 2, Epsilon: 0.010
# Episode 454, Reward: -13, Epsilon: 0.010
# Episode 455, Reward: 60, Epsilon: 0.010
# Episode 456, Reward: -40, Epsilon: 0.010
# Episode 457, Reward: 57, Epsilon: 0.010
# Episode 458, Reward: 55, Epsilon: 0.010
# Episode 459, Reward: 53, Epsilon: 0.010
# Episode 460, Reward: 58, Epsilon: 0.010
# Episode 461, Reward: 43, Epsilon: 0.010
# Episode 462, Reward: 58, Epsilon: 0.010
# Episode 463, Reward: -46, Epsilon: 0.010
# Episode 464, Reward: 59, Epsilon: 0.010
# Episode 465, Reward: 26, Epsilon: 0.010
# Episode 466, Reward: 55, Epsilon: 0.010
# Episode 467, Reward: 32, Epsilon: 0.010
# Episode 468, Reward: 62, Epsilon: 0.010
# Episode 469, Reward: 0, Epsilon: 0.010
# Episode 470, Reward: 60, Epsilon: 0.010
# Episode 471, Reward: 54, Epsilon: 0.010
# Episode 472, Reward: 10, Epsilon: 0.010
# Episode 473, Reward: 59, Epsilon: 0.010
# Episode 474, Reward: 40, Epsilon: 0.010
# Episode 475, Reward: 56, Epsilon: 0.010
# Episode 476, Reward: 54, Epsilon: 0.010
# Episode 477, Reward: 48, Epsilon: 0.010
# Episode 478, Reward: 13, Epsilon: 0.010
# Episode 479, Reward: 55, Epsilon: 0.010
# Episode 480, Reward: 15, Epsilon: 0.010
# Episode 481, Reward: 53, Epsilon: 0.010
# Episode 482, Reward: 60, Epsilon: 0.010
# Episode 483, Reward: 52, Epsilon: 0.010
# Episode 484, Reward: 48, Epsilon: 0.010
# Episode 485, Reward: 48, Epsilon: 0.010
# Episode 486, Reward: 47, Epsilon: 0.010
# Episode 487, Reward: 59, Epsilon: 0.010
# Episode 488, Reward: 48, Epsilon: 0.010
# Episode 489, Reward: 47, Epsilon: 0.010
# Episode 490, Reward: 26, Epsilon: 0.010
# Episode 491, Reward: 52, Epsilon: 0.010
# Episode 492, Reward: 8, Epsilon: 0.010
# Episode 493, Reward: 48, Epsilon: 0.010
# Episode 494, Reward: 54, Epsilon: 0.010
# Episode 495, Reward: -1, Epsilon: 0.010
# Episode 496, Reward: 55, Epsilon: 0.010
# Episode 497, Reward: 47, Epsilon: 0.010
# Episode 498, Reward: 55, Epsilon: 0.010
# Episode 499, Reward: 55, Epsilon: 0.010
# Episode 500, Reward: 56, Epsilon: 0.010
# Episode 501, Reward: 45, Epsilon: 0.010
# Episode 502, Reward: 30, Epsilon: 0.010
# Episode 503, Reward: -34, Epsilon: 0.010
# Episode 504, Reward: 49, Epsilon: 0.010
# Episode 505, Reward: 47, Epsilon: 0.010
# Episode 506, Reward: 49, Epsilon: 0.010
# Episode 507, Reward: 60, Epsilon: 0.010
# Episode 508, Reward: 44, Epsilon: 0.010
# Episode 509, Reward: 54, Epsilon: 0.010
# Episode 510, Reward: 1, Epsilon: 0.010
# Episode 511, Reward: 45, Epsilon: 0.010
# Episode 512, Reward: 59, Epsilon: 0.010
# Episode 513, Reward: 44, Epsilon: 0.010
# Episode 514, Reward: 44, Epsilon: 0.010
# Episode 515, Reward: 44, Epsilon: 0.010
# Episode 516, Reward: 48, Epsilon: 0.010
# Episode 517, Reward: 53, Epsilon: 0.010
# Episode 518, Reward: 5, Epsilon: 0.010
# Episode 519, Reward: 8, Epsilon: 0.010
# Episode 520, Reward: 59, Epsilon: 0.010
# Episode 521, Reward: 52, Epsilon: 0.010
# Episode 522, Reward: 58, Epsilon: 0.010
# Episode 523, Reward: 59, Epsilon: 0.010
# Episode 524, Reward: 44, Epsilon: 0.010
# Episode 525, Reward: 52, Epsilon: 0.010
# Episode 526, Reward: -141, Epsilon: 0.010
# Episode 527, Reward: -1, Epsilon: 0.010
# Episode 528, Reward: -103, Epsilon: 0.010
# Episode 529, Reward: -20, Epsilon: 0.010
# Episode 530, Reward: -80, Epsilon: 0.010
# Episode 531, Reward: 44, Epsilon: 0.010
# Episode 532, Reward: 57, Epsilon: 0.010
# Episode 533, Reward: -9, Epsilon: 0.010
# Episode 534, Reward: -16, Epsilon: 0.010
# Episode 535, Reward: 56, Epsilon: 0.010
# Episode 536, Reward: 45, Epsilon: 0.010
# Episode 537, Reward: -54, Epsilon: 0.010
# Episode 538, Reward: 53, Epsilon: 0.010
# Episode 539, Reward: 51, Epsilon: 0.010
# Episode 540, Reward: 50, Epsilon: 0.010
# Episode 541, Reward: 55, Epsilon: 0.010
# Episode 542, Reward: 48, Epsilon: 0.010
# Episode 543, Reward: 39, Epsilon: 0.010
# Episode 544, Reward: 55, Epsilon: 0.010
# Episode 545, Reward: 44, Epsilon: 0.010
# Episode 546, Reward: 55, Epsilon: 0.010
# Episode 547, Reward: 57, Epsilon: 0.010
# Episode 548, Reward: 44, Epsilon: 0.010
# Episode 549, Reward: 44, Epsilon: 0.010
# Episode 550, Reward: 46, Epsilon: 0.010
# Episode 551, Reward: 43, Epsilon: 0.010
# Episode 552, Reward: -21, Epsilon: 0.010
# Episode 553, Reward: 43, Epsilon: 0.010
# Episode 554, Reward: 53, Epsilon: 0.010
# Episode 555, Reward: 44, Epsilon: 0.010
# Episode 556, Reward: 49, Epsilon: 0.010
# Episode 557, Reward: 42, Epsilon: 0.010
# Episode 558, Reward: 44, Epsilon: 0.010
# Episode 559, Reward: 61, Epsilon: 0.010
# Episode 560, Reward: 52, Epsilon: 0.010
# Episode 561, Reward: 44, Epsilon: 0.010
# Episode 562, Reward: 52, Epsilon: 0.010
# Episode 563, Reward: 41, Epsilon: 0.010
# Episode 564, Reward: 41, Epsilon: 0.010
# Episode 565, Reward: 55, Epsilon: 0.010
# Episode 566, Reward: 42, Epsilon: 0.010
# Episode 567, Reward: 60, Epsilon: 0.010
# Episode 568, Reward: -3, Epsilon: 0.010
# Episode 569, Reward: 2, Epsilon: 0.010
# Episode 570, Reward: 1, Epsilon: 0.010
# Episode 571, Reward: 45, Epsilon: 0.010
# Episode 572, Reward: -11, Epsilon: 0.010
# Episode 573, Reward: -29, Epsilon: 0.010
# Episode 574, Reward: 49, Epsilon: 0.010
# Episode 575, Reward: 51, Epsilon: 0.010
# Episode 576, Reward: -13, Epsilon: 0.010
# Episode 577, Reward: 65, Epsilon: 0.010
# Episode 578, Reward: 48, Epsilon: 0.010
# Episode 579, Reward: 62, Epsilon: 0.010
# Episode 580, Reward: 48, Epsilon: 0.010
# Episode 581, Reward: 50, Epsilon: 0.010
# Episode 582, Reward: 54, Epsilon: 0.010
# Episode 583, Reward: 56, Epsilon: 0.010
# Episode 584, Reward: 41, Epsilon: 0.010
# Episode 585, Reward: 58, Epsilon: 0.010
# Episode 586, Reward: 52, Epsilon: 0.010
# Episode 587, Reward: 55, Epsilon: 0.010
# Episode 588, Reward: 56, Epsilon: 0.010
# Episode 589, Reward: 44, Epsilon: 0.010
# Episode 590, Reward: 56, Epsilon: 0.010
# Episode 591, Reward: 58, Epsilon: 0.010
# Episode 592, Reward: 52, Epsilon: 0.010
# Episode 593, Reward: 51, Epsilon: 0.010
# Episode 594, Reward: 60, Epsilon: 0.010
# Episode 595, Reward: 49, Epsilon: 0.010
# Episode 596, Reward: 41, Epsilon: 0.010
# Episode 597, Reward: 44, Epsilon: 0.010
# Episode 598, Reward: 59, Epsilon: 0.010
# Episode 599, Reward: 46, Epsilon: 0.010
# Episode 600, Reward: 48, Epsilon: 0.010
# Episode 601, Reward: 43, Epsilon: 0.010
# Episode 602, Reward: 44, Epsilon: 0.010
# Episode 603, Reward: 48, Epsilon: 0.010
# Episode 604, Reward: 56, Epsilon: 0.010
# Episode 605, Reward: 48, Epsilon: 0.010
# Episode 606, Reward: 47, Epsilon: 0.010
# Episode 607, Reward: 43, Epsilon: 0.010
# Episode 608, Reward: 55, Epsilon: 0.010
# Episode 609, Reward: 61, Epsilon: 0.010
# Episode 610, Reward: 56, Epsilon: 0.010
# Episode 611, Reward: 33, Epsilon: 0.010
# Episode 612, Reward: 55, Epsilon: 0.010
# Episode 613, Reward: 45, Epsilon: 0.010
# Episode 614, Reward: 44, Epsilon: 0.010
# Episode 615, Reward: 44, Epsilon: 0.010
# Episode 616, Reward: 60, Epsilon: 0.010
# Episode 617, Reward: 62, Epsilon: 0.010
# Episode 618, Reward: 57, Epsilon: 0.010
# Episode 619, Reward: 42, Epsilon: 0.010
# Episode 620, Reward: 49, Epsilon: 0.010
# Episode 621, Reward: 48, Epsilon: 0.010
# Episode 622, Reward: 56, Epsilon: 0.010
# Episode 623, Reward: 55, Epsilon: 0.010
# Episode 624, Reward: 53, Epsilon: 0.010
# Episode 625, Reward: 47, Epsilon: 0.010
# Episode 626, Reward: 60, Epsilon: 0.010
# Episode 627, Reward: 50, Epsilon: 0.010
# Episode 628, Reward: 40, Epsilon: 0.010
# Episode 629, Reward: 42, Epsilon: 0.010
# Episode 630, Reward: 43, Epsilon: 0.010
# Episode 631, Reward: 54, Epsilon: 0.010
# Episode 632, Reward: 48, Epsilon: 0.010
# Episode 633, Reward: 50, Epsilon: 0.010
# Episode 634, Reward: 60, Epsilon: 0.010
# Episode 635, Reward: 40, Epsilon: 0.010
# Episode 636, Reward: 49, Epsilon: 0.010
# Episode 637, Reward: -1, Epsilon: 0.010
# Episode 638, Reward: 55, Epsilon: 0.010
# Episode 639, Reward: 48, Epsilon: 0.010
# Episode 640, Reward: 55, Epsilon: 0.010
# Episode 641, Reward: 48, Epsilon: 0.010
# Episode 642, Reward: 48, Epsilon: 0.010
# Episode 643, Reward: 52, Epsilon: 0.010
# Episode 644, Reward: 43, Epsilon: 0.010
# Episode 645, Reward: 49, Epsilon: 0.010
# Episode 646, Reward: 41, Epsilon: 0.010
# Episode 647, Reward: 57, Epsilon: 0.010
# Episode 648, Reward: 53, Epsilon: 0.010
# Episode 649, Reward: 46, Epsilon: 0.010
# Episode 650, Reward: -6, Epsilon: 0.010
# Episode 651, Reward: 48, Epsilon: 0.010
# Episode 652, Reward: 43, Epsilon: 0.010
# Episode 653, Reward: 40, Epsilon: 0.010
# Episode 654, Reward: -176, Epsilon: 0.010
# Episode 655, Reward: 39, Epsilon: 0.010
# Episode 656, Reward: -44, Epsilon: 0.010
# Episode 657, Reward: 48, Epsilon: 0.010
# Episode 658, Reward: -300, Epsilon: 0.010
# Episode 659, Reward: 38, Epsilon: 0.010
# Episode 660, Reward: -13, Epsilon: 0.010
# Episode 661, Reward: -300, Epsilon: 0.010
# Episode 662, Reward: -17, Epsilon: 0.010
# Episode 663, Reward: -300, Epsilon: 0.010
# Episode 664, Reward: -300, Epsilon: 0.010
# Episode 665, Reward: -300, Epsilon: 0.010
# Episode 666, Reward: -300, Epsilon: 0.010
# Episode 667, Reward: -300, Epsilon: 0.010
# Episode 668, Reward: -300, Epsilon: 0.010
# Episode 669, Reward: -300, Epsilon: 0.010
# Episode 670, Reward: -300, Epsilon: 0.010
# Episode 671, Reward: -300, Epsilon: 0.010
# Episode 672, Reward: -300, Epsilon: 0.010
# Episode 673, Reward: -300, Epsilon: 0.010
# Episode 674, Reward: -300, Epsilon: 0.010
# Episode 675, Reward: -300, Epsilon: 0.010
# Episode 676, Reward: -300, Epsilon: 0.010
# Episode 677, Reward: -300, Epsilon: 0.010
# Episode 678, Reward: -300, Epsilon: 0.010
# Episode 679, Reward: -300, Epsilon: 0.010
# Episode 680, Reward: -300, Epsilon: 0.010
# Episode 681, Reward: -300, Epsilon: 0.010
# Episode 682, Reward: -300, Epsilon: 0.010
# Episode 683, Reward: -300, Epsilon: 0.010
# Episode 684, Reward: -300, Epsilon: 0.010
# Episode 685, Reward: -300, Epsilon: 0.010
# Episode 686, Reward: -300, Epsilon: 0.010
# Episode 687, Reward: -300, Epsilon: 0.010
# Episode 688, Reward: -300, Epsilon: 0.010
# Episode 689, Reward: -300, Epsilon: 0.010
# Episode 690, Reward: -178, Epsilon: 0.010
# Episode 691, Reward: -300, Epsilon: 0.010
# Episode 692, Reward: -300, Epsilon: 0.010
# Episode 693, Reward: -300, Epsilon: 0.010
# Episode 694, Reward: -300, Epsilon: 0.010
# Episode 695, Reward: -96, Epsilon: 0.010
# Episode 696, Reward: -300, Epsilon: 0.010
# Episode 697, Reward: -40, Epsilon: 0.010
# Episode 698, Reward: -300, Epsilon: 0.010
# Episode 699, Reward: -300, Epsilon: 0.010
# Episode 700, Reward: -300, Epsilon: 0.010
# Episode 701, Reward: -300, Epsilon: 0.010
# Episode 702, Reward: -180, Epsilon: 0.010
# Episode 703, Reward: -300, Epsilon: 0.010
# Episode 704, Reward: -26, Epsilon: 0.010
# Episode 705, Reward: -100, Epsilon: 0.010
# Episode 706, Reward: 14, Epsilon: 0.010
# Episode 707, Reward: -300, Epsilon: 0.010
# Episode 708, Reward: -104, Epsilon: 0.010
# Episode 709, Reward: -300, Epsilon: 0.010
# Episode 710, Reward: -300, Epsilon: 0.010
# Episode 711, Reward: -58, Epsilon: 0.010
# Episode 712, Reward: -300, Epsilon: 0.010
# Episode 713, Reward: -300, Epsilon: 0.010
# Episode 714, Reward: -300, Epsilon: 0.010
# Episode 715, Reward: -300, Epsilon: 0.010
# Episode 716, Reward: -300, Epsilon: 0.010
# Episode 717, Reward: -300, Epsilon: 0.010
# Episode 718, Reward: -300, Epsilon: 0.010
# Episode 719, Reward: -300, Epsilon: 0.010
# Episode 720, Reward: -300, Epsilon: 0.010
# Episode 721, Reward: -300, Epsilon: 0.010
# Episode 722, Reward: -300, Epsilon: 0.010
# Episode 723, Reward: -300, Epsilon: 0.010
# Episode 724, Reward: -54, Epsilon: 0.010
# Episode 725, Reward: -300, Epsilon: 0.010
# Episode 726, Reward: -300, Epsilon: 0.010
# Episode 727, Reward: -300, Epsilon: 0.010
# Episode 728, Reward: -300, Epsilon: 0.010
# Episode 729, Reward: -300, Epsilon: 0.010
# Episode 730, Reward: -300, Epsilon: 0.010
# Episode 731, Reward: -300, Epsilon: 0.010
# Episode 732, Reward: -300, Epsilon: 0.010
# Episode 733, Reward: -300, Epsilon: 0.010
# Episode 734, Reward: -300, Epsilon: 0.010
# Episode 735, Reward: -300, Epsilon: 0.010
# Episode 736, Reward: -300, Epsilon: 0.010
# Episode 737, Reward: -141, Epsilon: 0.010
# Episode 738, Reward: -300, Epsilon: 0.010
# Episode 739, Reward: -300, Epsilon: 0.010
# Episode 740, Reward: -300, Epsilon: 0.010
# Episode 741, Reward: -300, Epsilon: 0.010
# Episode 742, Reward: -300, Epsilon: 0.010
# Episode 743, Reward: -300, Epsilon: 0.010
# Episode 744, Reward: -300, Epsilon: 0.010
# Episode 745, Reward: -300, Epsilon: 0.010
# Episode 746, Reward: -300, Epsilon: 0.010
# Episode 747, Reward: -300, Epsilon: 0.010
# Episode 748, Reward: -151, Epsilon: 0.010
# Episode 749, Reward: -300, Epsilon: 0.010
# Episode 750, Reward: -300, Epsilon: 0.010
# Episode 751, Reward: -42, Epsilon: 0.010
# Episode 752, Reward: 4, Epsilon: 0.010
# Episode 753, Reward: -300, Epsilon: 0.010
# Episode 754, Reward: -300, Epsilon: 0.010
# Episode 755, Reward: -172, Epsilon: 0.010
# Episode 756, Reward: -300, Epsilon: 0.010
# Episode 757, Reward: -300, Epsilon: 0.010
# Episode 758, Reward: -300, Epsilon: 0.010
# Episode 759, Reward: -300, Epsilon: 0.010
# Episode 760, Reward: -300, Epsilon: 0.010
# Episode 761, Reward: 34, Epsilon: 0.010
# Episode 762, Reward: -198, Epsilon: 0.010
# Episode 763, Reward: -42, Epsilon: 0.010
# Episode 764, Reward: 41, Epsilon: 0.010
# Episode 765, Reward: -121, Epsilon: 0.010
# Episode 766, Reward: 52, Epsilon: 0.010
# Episode 767, Reward: -3, Epsilon: 0.010
# Episode 768, Reward: 39, Epsilon: 0.010
# Episode 769, Reward: 19, Epsilon: 0.010
# Episode 770, Reward: 56, Epsilon: 0.010
# Episode 771, Reward: -40, Epsilon: 0.010
# Episode 772, Reward: 39, Epsilon: 0.010
# Episode 773, Reward: -99, Epsilon: 0.010
# Episode 774, Reward: 33, Epsilon: 0.010
# Episode 775, Reward: 24, Epsilon: 0.010
# Episode 776, Reward: 59, Epsilon: 0.010
# Episode 777, Reward: 53, Epsilon: 0.010
# Episode 778, Reward: 40, Epsilon: 0.010
# Episode 779, Reward: 46, Epsilon: 0.010
# Episode 780, Reward: 4, Epsilon: 0.010
# Episode 781, Reward: -37, Epsilon: 0.010
# Episode 782, Reward: -39, Epsilon: 0.010
# Episode 783, Reward: 23, Epsilon: 0.010
# Episode 784, Reward: 45, Epsilon: 0.010
# Episode 785, Reward: 33, Epsilon: 0.010
# Episode 786, Reward: 59, Epsilon: 0.010
# Episode 787, Reward: 42, Epsilon: 0.010
# Episode 788, Reward: 33, Epsilon: 0.010
# Episode 789, Reward: 36, Epsilon: 0.010
# Episode 790, Reward: 53, Epsilon: 0.010
# Episode 791, Reward: 31, Epsilon: 0.010
# Episode 792, Reward: 35, Epsilon: 0.010
# Episode 793, Reward: 59, Epsilon: 0.010
# Episode 794, Reward: 40, Epsilon: 0.010
# Episode 795, Reward: 37, Epsilon: 0.010
# Episode 796, Reward: 61, Epsilon: 0.010
# Episode 797, Reward: 51, Epsilon: 0.010
# Episode 798, Reward: 36, Epsilon: 0.010
# Episode 799, Reward: -55, Epsilon: 0.010
# Episode 800, Reward: 60, Epsilon: 0.010
# Episode 801, Reward: 25, Epsilon: 0.010
# Episode 802, Reward: 35, Epsilon: 0.010
# Episode 803, Reward: 9, Epsilon: 0.010
# Episode 804, Reward: 32, Epsilon: 0.010
# Episode 805, Reward: 50, Epsilon: 0.010
# Episode 806, Reward: 48, Epsilon: 0.010
# Episode 807, Reward: 42, Epsilon: 0.010
# Episode 808, Reward: 35, Epsilon: 0.010
# Episode 809, Reward: 51, Epsilon: 0.010
# Episode 810, Reward: 36, Epsilon: 0.010
# Episode 811, Reward: 53, Epsilon: 0.010
# Episode 812, Reward: 37, Epsilon: 0.010
# Episode 813, Reward: 55, Epsilon: 0.010
# Episode 814, Reward: -1, Epsilon: 0.010
# Episode 815, Reward: -9, Epsilon: 0.010
# Episode 816, Reward: 44, Epsilon: 0.010
# Episode 817, Reward: -15, Epsilon: 0.010
# Episode 818, Reward: 39, Epsilon: 0.010
# Episode 819, Reward: 45, Epsilon: 0.010
# Episode 820, Reward: 54, Epsilon: 0.010
# Episode 821, Reward: 62, Epsilon: 0.010
# Episode 822, Reward: 51, Epsilon: 0.010
# Episode 823, Reward: 43, Epsilon: 0.010
# Episode 824, Reward: 58, Epsilon: 0.010
# Episode 825, Reward: 40, Epsilon: 0.010
# Episode 826, Reward: 0, Epsilon: 0.010
# Episode 827, Reward: -10, Epsilon: 0.010
# Episode 828, Reward: -6, Epsilon: 0.010
# Episode 829, Reward: -24, Epsilon: 0.010
# Episode 830, Reward: -16, Epsilon: 0.010
# Episode 831, Reward: 56, Epsilon: 0.010
# Episode 832, Reward: 60, Epsilon: 0.010
# Episode 833, Reward: 27, Epsilon: 0.010
# Episode 834, Reward: 43, Epsilon: 0.010
# Episode 835, Reward: 55, Epsilon: 0.010
# Episode 836, Reward: 42, Epsilon: 0.010
# Episode 837, Reward: 20, Epsilon: 0.010
# Episode 838, Reward: 64, Epsilon: 0.010
# Episode 839, Reward: 26, Epsilon: 0.010
# Episode 840, Reward: -42, Epsilon: 0.010
# Episode 841, Reward: 33, Epsilon: 0.010
# Episode 842, Reward: 56, Epsilon: 0.010
# Episode 843, Reward: -32, Epsilon: 0.010
# Episode 844, Reward: 44, Epsilon: 0.010
# Episode 845, Reward: 64, Epsilon: 0.010
# Episode 846, Reward: 52, Epsilon: 0.010
# Episode 847, Reward: 56, Epsilon: 0.010
# Episode 848, Reward: 27, Epsilon: 0.010
# Episode 849, Reward: 47, Epsilon: 0.010
# Episode 850, Reward: -71, Epsilon: 0.010
# Episode 851, Reward: -20, Epsilon: 0.010
# Episode 852, Reward: 60, Epsilon: 0.010
# Episode 853, Reward: 57, Epsilon: 0.010
# Episode 854, Reward: -41, Epsilon: 0.010
# Episode 855, Reward: 35, Epsilon: 0.010
# Episode 856, Reward: 50, Epsilon: 0.010
# Episode 857, Reward: 60, Epsilon: 0.010
# Episode 858, Reward: 46, Epsilon: 0.010
# Episode 859, Reward: 59, Epsilon: 0.010
# Episode 860, Reward: 46, Epsilon: 0.010
# Episode 861, Reward: 55, Epsilon: 0.010
# Episode 862, Reward: 51, Epsilon: 0.010
# Episode 863, Reward: 50, Epsilon: 0.010
# Episode 864, Reward: 54, Epsilon: 0.010
# Episode 865, Reward: -7, Epsilon: 0.010
# Episode 866, Reward: 48, Epsilon: 0.010
# Episode 867, Reward: 63, Epsilon: 0.010
# Episode 868, Reward: 61, Epsilon: 0.010
# Episode 869, Reward: 50, Epsilon: 0.010
# Episode 870, Reward: -19, Epsilon: 0.010
# Episode 871, Reward: -9, Epsilon: 0.010
# Episode 872, Reward: 21, Epsilon: 0.010
# Episode 873, Reward: 61, Epsilon: 0.010
# Episode 874, Reward: 64, Epsilon: 0.010
# Episode 875, Reward: 57, Epsilon: 0.010
# Episode 876, Reward: 64, Epsilon: 0.010
# Episode 877, Reward: -36, Epsilon: 0.010
# Episode 878, Reward: 55, Epsilon: 0.010
# Episode 879, Reward: 56, Epsilon: 0.010
# Episode 880, Reward: 16, Epsilon: 0.010
# Episode 881, Reward: 47, Epsilon: 0.010
# Episode 882, Reward: 51, Epsilon: 0.010
# Episode 883, Reward: 24, Epsilon: 0.010
# Episode 884, Reward: 26, Epsilon: 0.010
# Episode 885, Reward: 49, Epsilon: 0.010
# Episode 886, Reward: 29, Epsilon: 0.010
# Episode 887, Reward: 55, Epsilon: 0.010
# Episode 888, Reward: 48, Epsilon: 0.010
# Episode 889, Reward: 48, Epsilon: 0.010
# Episode 890, Reward: 44, Epsilon: 0.010
# Episode 891, Reward: 57, Epsilon: 0.010
# Episode 892, Reward: 62, Epsilon: 0.010
# Episode 893, Reward: 26, Epsilon: 0.010
# Episode 894, Reward: 57, Epsilon: 0.010
# Episode 895, Reward: 55, Epsilon: 0.010
# Episode 896, Reward: 51, Epsilon: 0.010
# Episode 897, Reward: 36, Epsilon: 0.010
# Episode 898, Reward: 60, Epsilon: 0.010
# Episode 899, Reward: 38, Epsilon: 0.010
# Episode 900, Reward: 44, Epsilon: 0.010
# Episode 901, Reward: 28, Epsilon: 0.010
# Episode 902, Reward: 40, Epsilon: 0.010
# Episode 903, Reward: 58, Epsilon: 0.010
# Episode 904, Reward: 45, Epsilon: 0.010
# Episode 905, Reward: -20, Epsilon: 0.010
# Episode 906, Reward: 46, Epsilon: 0.010
# Episode 907, Reward: 51, Epsilon: 0.010
# Episode 908, Reward: 60, Epsilon: 0.010
# Episode 909, Reward: 40, Epsilon: 0.010
# Episode 910, Reward: 51, Epsilon: 0.010
# Episode 911, Reward: 54, Epsilon: 0.010
# Episode 912, Reward: 57, Epsilon: 0.010
# Episode 913, Reward: 58, Epsilon: 0.010
# Episode 914, Reward: 56, Epsilon: 0.010
# Episode 915, Reward: 53, Epsilon: 0.010
# Episode 916, Reward: 43, Epsilon: 0.010
# Episode 917, Reward: 45, Epsilon: 0.010
# Episode 918, Reward: 62, Epsilon: 0.010
# Episode 919, Reward: 44, Epsilon: 0.010
# Episode 920, Reward: 52, Epsilon: 0.010
# Episode 921, Reward: 41, Epsilon: 0.010
# Episode 922, Reward: 46, Epsilon: 0.010
# Episode 923, Reward: 51, Epsilon: 0.010
# Episode 924, Reward: -10, Epsilon: 0.010
# Episode 925, Reward: 50, Epsilon: 0.010
# Episode 926, Reward: 43, Epsilon: 0.010
# Episode 927, Reward: 52, Epsilon: 0.010
# Episode 928, Reward: 45, Epsilon: 0.010
# Episode 929, Reward: 64, Epsilon: 0.010
# Episode 930, Reward: 54, Epsilon: 0.010
# Episode 931, Reward: 56, Epsilon: 0.010
# Episode 932, Reward: 52, Epsilon: 0.010
# Episode 933, Reward: 37, Epsilon: 0.010
# Episode 934, Reward: 56, Epsilon: 0.010
# Episode 935, Reward: 34, Epsilon: 0.010
# Episode 936, Reward: 55, Epsilon: 0.010
# Episode 937, Reward: 51, Epsilon: 0.010
# Episode 938, Reward: 46, Epsilon: 0.010
# Episode 939, Reward: -18, Epsilon: 0.010
# Episode 940, Reward: 52, Epsilon: 0.010
# Episode 941, Reward: 46, Epsilon: 0.010
# Episode 942, Reward: 30, Epsilon: 0.010
# Episode 943, Reward: 54, Epsilon: 0.010
# Episode 944, Reward: 54, Epsilon: 0.010
# Episode 945, Reward: 42, Epsilon: 0.010
# Episode 946, Reward: 58, Epsilon: 0.010
# Episode 947, Reward: 53, Epsilon: 0.010
# Episode 948, Reward: 55, Epsilon: 0.010
# Episode 949, Reward: 60, Epsilon: 0.010
# Episode 950, Reward: 31, Epsilon: 0.010
# Episode 951, Reward: 56, Epsilon: 0.010
# Episode 952, Reward: 58, Epsilon: 0.010
# Episode 953, Reward: 52, Epsilon: 0.010
# Episode 954, Reward: 47, Epsilon: 0.010
# Episode 955, Reward: 42, Epsilon: 0.010
# Episode 956, Reward: 53, Epsilon: 0.010
# Episode 957, Reward: 59, Epsilon: 0.010
# Episode 958, Reward: 50, Epsilon: 0.010
# Episode 959, Reward: 15, Epsilon: 0.010
# Episode 960, Reward: 62, Epsilon: 0.010
# Episode 961, Reward: 44, Epsilon: 0.010
# Episode 962, Reward: 44, Epsilon: 0.010
# Episode 963, Reward: 50, Epsilon: 0.010
# Episode 964, Reward: 20, Epsilon: 0.010
# Episode 965, Reward: 51, Epsilon: 0.010
# Episode 966, Reward: -19, Epsilon: 0.010
# Episode 967, Reward: 54, Epsilon: 0.010
# Episode 968, Reward: 62, Epsilon: 0.010
# Episode 969, Reward: 50, Epsilon: 0.010
# Episode 970, Reward: 44, Epsilon: 0.010
# Episode 971, Reward: 52, Epsilon: 0.010
# Episode 972, Reward: -9, Epsilon: 0.010
# Episode 973, Reward: 50, Epsilon: 0.010
# Episode 974, Reward: 53, Epsilon: 0.010
# Episode 975, Reward: 34, Epsilon: 0.010
# Episode 976, Reward: 53, Epsilon: 0.010
# Episode 977, Reward: 65, Epsilon: 0.010
# Episode 978, Reward: 54, Epsilon: 0.010
# Episode 979, Reward: 54, Epsilon: 0.010
# Episode 980, Reward: 36, Epsilon: 0.010
# Episode 981, Reward: 60, Epsilon: 0.010
# Episode 982, Reward: 58, Epsilon: 0.010
# Episode 983, Reward: 56, Epsilon: 0.010
# Episode 984, Reward: 52, Epsilon: 0.010
# Episode 985, Reward: 40, Epsilon: 0.010
# Episode 986, Reward: 52, Epsilon: 0.010
# Episode 987, Reward: 50, Epsilon: 0.010
# Episode 988, Reward: 45, Epsilon: 0.010
# Episode 989, Reward: 56, Epsilon: 0.010
# Episode 990, Reward: 49, Epsilon: 0.010
# Episode 991, Reward: 49, Epsilon: 0.010
# Episode 992, Reward: 46, Epsilon: 0.010
# Episode 993, Reward: 57, Epsilon: 0.010
# Episode 994, Reward: 49, Epsilon: 0.010
# Episode 995, Reward: 56, Epsilon: 0.010
# Episode 996, Reward: 62, Epsilon: 0.010
# Episode 997, Reward: 55, Epsilon: 0.010
# Episode 998, Reward: 51, Epsilon: 0.010
# Episode 999, Reward: 52, Epsilon: 0.010
# Episode 1000, Reward: 51, Epsilon: 0.010
