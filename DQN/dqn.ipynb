# %%
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from tqdm import tqdm
from rl_glue import RLGlue

from tbu_gym.tbu_discrete import TruckBackerEnv_D

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-5, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, buffer_size=50000, batch_size=64):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.memory = deque(maxlen=buffer_size)
        # device, not needed, but needed if going on canada compute to specify gpu
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.q_nn = self.build_nn().to(self.device) # build q network
        self.target_net = self.build_nn().to(self.device) # build target network
        self.target_net.load_state_dict(self.q_nn.state_dict()) # make target net same as q net. initialization is random so need this
        self.optimizer = optim.Adam(self.q_nn.parameters(), lr=lr) 
        
    def build_nn(self): # to build the q network, 2 hiddne layer with relu and 128 neuronsin each
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_dim)
        )
    
    def agent_policy(self, state): # act e greedy
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim) # rand action
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device) # convert state to tensor, then add batch dimension, then move to device
        with torch.no_grad(): # dont calculate gradients, no need
            q_values = self.q_nn(state)
        return q_values.argmax().item()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # store transition sars, done is if terminal state
    
    def train_with_mem(self): # train with experience from memory using batch size set in agent
        if len(self.memory) < self.batch_size: # if not enought mem, could be changed to use what we have instead of skip
            return
        batch = random.sample(self.memory, self.batch_size) # get batch
        states, actions, rewards, next_states, dones = zip(*batch) # get batch features

        # convert data to tensors which can be used by pytorch
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device) 
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # get current q values from q network
        q_values = self.q_nn(states).gather(1, actions)

        # use the samples from experience batch to calc target network q values
        with torch.no_grad(): # no need to calc gradients for target
            next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]  
        # target = r + gamma * max_a' Q(s', a') * (1 - done)
        target = rewards + self.gamma * next_q_values * (1 - dones)

        # mean squared error 
        errors = target - q_values
        squared_errors = errors ** 2
        mean_squared_error = torch.mean(squared_errors)

        self.optimizer.zero_grad()
        mean_squared_error.backward()
        self.optimizer.step()
 
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay 

    
    def update_target(self): # update target network replacing it with the current q network
        self.target_net.load_state_dict(self.q_nn.state_dict())

# %%
import numpy as np
from tbu_gym.tbu_discrete import TruckBackerEnv_D
import matplotlib.pyplot as plt

#hyper params, these are set by default in the agent but can be changed here
num_episodes = 1000
max_steps_per_episode = 500
gamma = 0.99
learning_rate = 1e-3
epsilon_start = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01
batch_size = 64
target_update_freq = 10  # Update target network every N episodes

#agent env setup
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

agent = DQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    lr=learning_rate,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    epsilon_min=epsilon_min,
    batch_size=batch_size
)

#training
episode_rewards = []

for episode in range(1, num_episodes + 1):
    state = env.reset()
    total_reward = 0

    for t in range(max_steps_per_episode):
    
        action = agent.agent_policy(state) # e greedy action

        # step env
        next_state, reward, done, info = env.step(action) # do a observe s',r and if terminal
        total_reward += reward

        #store transition in memory
        agent.remember(state, action, reward, next_state, done) # set s' = s a r and if terminal

        # train agent with memory, will train with batch size set in agent
        agent.train_with_mem() 

        state = next_state #s = s'

        if done: # if terminal state
            break


    if episode % target_update_freq == 0:
        agent.update_target()

    episode_rewards.append(total_reward)
    
    print(f"Episode {episode}, Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")


plt.plot(episode_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN Training on TruckBackerEnv_D')
plt.show()
# Out:
# Episode 1, Reward: -300, Epsilon: 0.305
# Episode 2, Reward: -300, Epsilon: 0.068
# Episode 3, Reward: -300, Epsilon: 0.015
# Episode 4, Reward: -300, Epsilon: 0.010
# Episode 5, Reward: -300, Epsilon: 0.010
# Episode 6, Reward: -300, Epsilon: 0.010
# Episode 7, Reward: -300, Epsilon: 0.010
# Episode 8, Reward: -300, Epsilon: 0.010
# Episode 9, Reward: -300, Epsilon: 0.010
# Episode 10, Reward: -300, Epsilon: 0.010
# Episode 11, Reward: -300, Epsilon: 0.010
# Episode 12, Reward: -300, Epsilon: 0.010
# Episode 13, Reward: -300, Epsilon: 0.010
# Episode 14, Reward: -300, Epsilon: 0.010
# Episode 15, Reward: -300, Epsilon: 0.010
# Episode 16, Reward: -300, Epsilon: 0.010
# Episode 17, Reward: -300, Epsilon: 0.010
# Episode 18, Reward: -300, Epsilon: 0.010
# Episode 19, Reward: -300, Epsilon: 0.010
# Episode 20, Reward: -300, Epsilon: 0.010
# Episode 21, Reward: -300, Epsilon: 0.010
# Episode 22, Reward: -300, Epsilon: 0.010
# Episode 23, Reward: -300, Epsilon: 0.010
# Episode 24, Reward: -300, Epsilon: 0.010
# Episode 25, Reward: -300, Epsilon: 0.010
# Episode 26, Reward: -300, Epsilon: 0.010
# Episode 27, Reward: -300, Epsilon: 0.010
# Episode 28, Reward: -300, Epsilon: 0.010
# Episode 29, Reward: -300, Epsilon: 0.010
# Episode 30, Reward: -300, Epsilon: 0.010
# Episode 31, Reward: -300, Epsilon: 0.010
# Episode 32, Reward: -300, Epsilon: 0.010
# Episode 33, Reward: -300, Epsilon: 0.010
# Episode 34, Reward: -300, Epsilon: 0.010
# Episode 35, Reward: -300, Epsilon: 0.010
# Episode 36, Reward: -300, Epsilon: 0.010
# Episode 37, Reward: -300, Epsilon: 0.010
# Episode 38, Reward: -300, Epsilon: 0.010
# Episode 39, Reward: -300, Epsilon: 0.010
# Episode 40, Reward: -300, Epsilon: 0.010
# Episode 41, Reward: -300, Epsilon: 0.010
# Episode 42, Reward: -300, Epsilon: 0.010
# Episode 43, Reward: -300, Epsilon: 0.010
# Episode 44, Reward: -300, Epsilon: 0.010
# Episode 45, Reward: -300, Epsilon: 0.010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[184], line 51
#      48 agent.remember(state, action, reward, next_state, done) # set s' = s a r and if terminal
#      50 # train agent with memory, will train with batch size set in agent
# ---> 51 agent.train_with_mem()
#      53 state = next_state #s = s'
#      55 if done: # if terminal state
#
# Cell In[183], line 75, in DQNAgent.train_with_mem(self)
#      73 self.optimizer.zero_grad()
#      74 mean_squared_error.backward()
# ---> 75 self.optimizer.step()
#      77 if self.epsilon > self.epsilon_min:
#      78     self.epsilon *= self.epsilon_decay
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File ~/Desktop/CMPUT655-Project/.venv/lib/python3.11/site-packages/torch/optim/adam.py:447, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     444     device_beta1 = beta1
#     446 # Decay the first and second moment running average coefficient
# --> 447 exp_avg.lerp_(grad, 1 - device_beta1)
#     449 # Nested if is necessary to bypass jitscript rules
#     450 if differentiable and isinstance(beta2, Tensor):
#
# KeyboardInterrupt:
